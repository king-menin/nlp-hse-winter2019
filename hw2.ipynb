# %% [markdown]
# # Автоматическая обработка текстов
# ## Дистрибутивная семантика
#
# В данном задании предлагается реализовать "диалог с поэтом":
#
# написать функцию, которая на вход принимает произвольную фразу и возвращает "ближающую" к ней цитату выбранного вами поэта.
#
# Можно выдавать точный "кусок", если фраза совпадает с частью какого-либо стихотворения.
#
# Примеры:
#
# * query("у лукоморья")
#
# > У лукоморья дуб зеленый;
#
# > Златая цепь на дубе том
#
# > И днем и ночью кот ученый
#
# > Все ходит по цепи кругом;
#
# * query("Я хочу прыгнуть с крыши")
#
# > Я думала провести вас по потаенной лестнице, но надобно идти мимо спальни, а я боюсь.
#
# Больше примеров тут: @SberPushkinBot
#
# ### Часть 1
# * Соберите данные вашего любимого (или не очень) поэта.
# * Нарежте на тексты четверостишья, или куски больше. Как формировать потенциальные ответы выбираете сами.
#
# ### Часть 2
# Исследование коллекции
#
# * Визуализируйте часть слов полученное коллекции (TSNE).
# * Сделайте выводы о ее структуре, если это возможно.
#
# ### Часть 3
# Реализация алгоритма
#
# * Предлагается векторизовать получившиеся фрагменты в части 1.
# * Искать близкие к запросу по выбранной мере близости (например cos) фрагменты.

# %%
<your code here>
